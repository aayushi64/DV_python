# %%
#conditional statements allow you to run 
# different blocks of code depending on user input or conditions. The most common ones are if, elif, and else.
# Ask user for a number
num = int(input("Enter a number: "))

if num > 0:
    print("Positive number")
elif num == 0:
    print("Zero")
else:
    print("Negative number")

# %%
# Ask user for age
# ':' means to satrt the block of code that will be executed if the condition is true.
# The code inside the block should be indented.
age = int(input("Enter your age: "))

if age < 13:
    print("You are a child.")
elif age < 20:
    print("You are a teenager.")
elif age < 60:
    print("You are an adult.")
else:
    print("You are a senior citizen.")

# %%
age = int (input("enter your age: "))
if age < 3 :
    print("you are a toddler")
elif age <7 :
    print ("you are a child.")
elif age<20 :
    print ("you aree a teenager.")
elif age < 60 :
    print ("you are an adult.")

# %%
years = int(input("Enter the number of years: "))
if years < 1981:
    print("Generation X")
elif years < 1997:
    print("Millennial") 
elif  years < 2012:
    print("Gen Z")
elif years < 2025:
    print("Gen Alpha")
elif years < 2035:
    print("Gen Beta")
# condition dete wqt you can either skip or include parenthesis

# %%
num = int(input("Enter a number: "))

if num == 0:
    print("The number is Zero")
elif num > 0:
    if num % 2 == 0:
        print("Positive Even number")
    else:
        print("Positive Odd number")
else:
    if num % 2 == 0:
        print("Negative Even number")
    else:
        print("Negative Odd number")

# %%
#leap year
year = int(input("Enter a year: "))

if (year % 400 == 0):
    print("Leap Year")
elif (year % 100 == 0):
    print("Not a Leap Year")
elif (year % 4 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")

# %%
#operations function 
#tested if else condtion
year = int(input("Enter a year: "))

# Using combined conditions
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")

# %%
# Simple Calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
op = input("Enter operation (+, -, *, /): ")
# string main denge hum operators ko 
#nahi toh voh use arthmetic operations main le lega 
if op == '+':
    print("Result:", num1 + num2)
elif op == '-':
    print("Result:", num1 - num2)
elif op == '*':
    print("Result:", num1 * num2)
elif op == '/':
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        # error hona chaiye print main 
        print("Error: Division by zero not allowed")
else:
    print("Invalid operation")
# Out:
# Error: Division by zero not allowed

# %%
age = int (input("Provide your age :"))
amt = 360
price = amt - 100
seniorcitizen = amt - 200
if age<10 :
    print ("you are a child, thus not allowded")
elif age <15 :
    print ("you are a student ,your respective age is :" ,age, "amount to be paid is :", price)
elif age <45 :
    print ("you are an adult, your respective age is :",age , "amount to be paid is :" ,amt)
else :
    print ("you are senior citizen, your respective age is : ",age, "amount to be paid is :",seniorcitizen)
# Out:
# you are senior citizen, your respective age is :  65 amount to be paid is : 160
