# %%
a=15

b=12

print(a>b)

print(a<b)

print(a==b)

print(a!=b)

print(a>=b)

print(a<=b)

# %%
a=12

b=10

print(a&b)#bitwine AND

print(a|b)#bitwise OR

print(~a)#bitwise NOT

print(a^b)#bitwise XOR

print(a>>b)#bitwise right shift

print(a<<b)#bitwise left shift
# Out:
# 8
# 14
# -13
# 6
# 0
# 12288

# %%
#Assignment operator

a=15

b=13

c=17

d=30

e=23

f=6

g=13

h=7

i=9

j=15

a+=5

print(a)

b-=10

print(b)

c*=19

print(c)

d/=12

print(d)

e**=2

print(e)

f&=10

print(f)

g|=2

print(g)

h^=4

print(h)

i>>=4

print(i)

j<<=5

print(j)
