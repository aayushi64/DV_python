# %%
# To Print "Hello, World!" to the console
print("Hello, World!")

# %%
# To assign a value to a variable
a = 10
print (a)

# %%
# To get the type of a variable
# in jupiter notebook you have to use print(type(a)) to get the type of a variable
b = "hello"
print (b)
print(type(b))
c = 3.14
print(c)
print(type(c))
e = 10+3j
print(e)
print(type(e))
